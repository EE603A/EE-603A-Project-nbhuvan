# %%
from matplotlib import image
from matplotlib import pyplot
from numpy import asarray

# %%
image_1 = image.imread('lena_color.png')
image_2 = image.imread('lena_gray.png')

# %%
print(image_1.dtype)
print(image_1.shape)

pyplot.imshow(image_1)
pyplot.show()
# Out:
# float32
# (512, 512, 4)

# %%
print(image_2.dtype)
print(image_2.shape)

pyplot.imshow(image_2)
pyplot.show()
# Out:
# float32
# (512, 512)

# %%
data_1 = asarray(image_1)
print(type(data_1))
print(data_1.shape)
print(data_1)
# Out:
# <class 'numpy.ndarray'>
# (512, 512, 4)
# [[[0.87058824 0.52156866 0.4745098  1.        ]
#   [0.87058824 0.52156866 0.4745098  1.        ]
#   [0.8862745  0.5372549  0.5058824  1.        ]
#   ...
#   [0.8862745  0.5686275  0.4745098  1.        ]
#   [0.85490197 0.4745098  0.4117647  1.        ]
#   [0.7764706  0.3647059  0.34901962 1.        ]]
#
#  [[0.87058824 0.52156866 0.4745098  1.        ]
#   [0.87058824 0.52156866 0.4745098  1.        ]
#   [0.8862745  0.5372549  0.5058824  1.        ]
#   ...
#   [0.8862745  0.5686275  0.4745098  1.        ]
#   [0.85490197 0.4745098  0.4117647  1.        ]
#   [0.7764706  0.3647059  0.34901962 1.        ]]
#
#  [[0.87058824 0.52156866 0.4745098  1.        ]
#   [0.87058824 0.52156866 0.4745098  1.        ]
#   [0.8862745  0.5372549  0.5058824  1.        ]
#   ...
#   [0.8862745  0.5686275  0.4745098  1.        ]
#   [0.85490197 0.4745098  0.4117647  1.        ]
#   [0.7764706  0.3647059  0.34901962 1.        ]]
#
#  ...
#
#  [[0.3137255  0.0627451  0.21960784 1.        ]
#   [0.3137255  0.0627451  0.21960784 1.        ]
#   [0.34901962 0.07843138 0.20392157 1.        ]
#   ...
#   [0.6666667  0.2509804  0.3137255  1.        ]
#   [0.68235296 0.2509804  0.28235295 1.        ]
#   [0.6666667  0.21960784 0.28235295 1.        ]]
#
#  [[0.3137255  0.0627451  0.21960784 1.        ]
#   [0.3137255  0.0627451  0.21960784 1.        ]
#   [0.3647059  0.09411765 0.2509804  1.        ]
#   ...
#   [0.69803923 0.26666668 0.29803923 1.        ]
#   [0.69803923 0.26666668 0.29803923 1.        ]
#   [0.7137255  0.26666668 0.29803923 1.        ]]
#
#  [[0.3137255  0.0627451  0.21960784 1.        ]
#   [0.3137255  0.0627451  0.21960784 1.        ]
#   [0.3647059  0.09411765 0.2509804  1.        ]
#   ...
#   [0.69803923 0.26666668 0.29803923 1.        ]
#   [0.69803923 0.26666668 0.29803923 1.        ]
#   [0.7137255  0.26666668 0.29803923 1.        ]]]

# %%
data_2 = asarray(image_2)
print(type(data_2))
print(data_2.shape)
print(data_2)
# Out:
# <class 'numpy.ndarray'>
# (512, 512)
# [[0.63529414 0.63529414 0.63529414 ... 0.6666667  0.60784316 0.5019608 ]
#  [0.63529414 0.63529414 0.63529414 ... 0.6666667  0.60784316 0.5019608 ]
#  [0.63529414 0.63529414 0.63529414 ... 0.6666667  0.60784316 0.5019608 ]
#  ...
#  [0.16862746 0.16862746 0.19607843 ... 0.40784314 0.39215687 0.38431373]
#  [0.17254902 0.17254902 0.21568628 ... 0.40784314 0.4117647  0.42352942]
#  [0.17254902 0.17254902 0.21568628 ... 0.40784314 0.4117647  0.42352942]]
